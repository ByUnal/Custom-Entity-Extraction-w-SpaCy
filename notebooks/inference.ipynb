# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import re

import string
import nltk
nltk.download('stopwords')

#Stop words present in the library
stopwords = nltk.corpus.stopwords.words('english')

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\m84246307\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Load data
df = pd.read_csv("../data/jobpostings.csv")

# Remove all duplicate rows 
df = df.drop_duplicates(keep='last')

# %%
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

#defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stopwords])

def preprocessing(description):
    
    # remove punctuation
    description = remove_punctuation(str(description))
                                                            
    # lowering the text
    description = description.lower()
    
    # remove stopwords
    description = remove_stopwords(description)
    
    return description

# %%
df_tech = pd.read_excel("../data/Technology Skills.xlsx")
tech_skills = list(df_tech["Example"].unique())

df_skill = pd.read_excel("../data/Skills.xlsx")
regular_skills = list(df_skill["Element Name"].unique())

# %%
train, test = train_test_split(df, test_size=0.2, random_state=14, shuffle=True)
train = train.reset_index()
test = test.reset_index()

# %%
# Preprocessing...
for idx, row in tqdm(test.iterrows()):
    test['Job Description'][idx] = preprocessing(test['Job Description'][idx])
# Out:
# 37726it [01:18, 482.15it/s]

# %%
import spacy
from spacy.tokens import DocBin

# model_test = test["Job Description"][10]

# load the trained model
nlp_output = spacy.load("../output/model-best")

category_list = []

# Preprocessing...
for idx, row in tqdm(test.iterrows()):
    # pass our test instance into the trained pipeline
    doc = nlp_output(test["Job Description"][idx])
    
    obj = {"Job Id": test["Job Id"][idx],"Entity Values": list(doc.ents)}
    category_list.append(obj)
# Out:
# 37726it [26:48, 23.45it/s]

# %%
cols = ['JOB ID', 'Entity Values']
lst = []
for idx in tqdm(range(len(category_list))):
    entities = [str(s) for s in category_list[idx]["Entity Values"]]
    lst.append([category_list[idx]["Job Id"], 
                entities])
df_categories = pd.DataFrame(lst, columns=cols)

# %%
df_categories

# %% [markdown]
# # Create Similarity Score

# %%
# !python -m spacy download en_core_web_md

# %%
nlp = spacy.load('en_core_web_md')

# %%
x_embed = [nlp(skill).vector for skill in x]
y_embed = [nlp(skill).vector for skill in y]

# %%
def cos_similarity(x,y):
    """ return cosine similarity between two lists """
    x_embed = nlp(str(x)).vector
    y_embed = nlp(str(y)).vector
    
    numerator = sum(a*b for a,b in zip(x_embed,y_embed))
    squared_sum_x = sum(i*i for i in x_embed)
    squared_sum_y = sum(i*i for i in y_embed)
    
    denominator = squared_sum_x*squared_sum_y
    return round(numerator/float(denominator),3)

# %%
def find_similarity(first_set, sec_set):
    sums = 0.0
    for fs in first_set:
        for ss in sec_set:
            sums += cos_similarity(fs, ss)
            
            # If they both in tech skills, reward
            if (str(fs) in tech_skills) and (str(ss) in tech_skills):
                print("tech")
                sums += 0.01
                
            # If they both in regular skills, reward   
            if (str(fs) in regular_skills) and (str(ss) in regular_skills):
                print("regular")
                sums += 0.01
    return sums

# %%
lst = []
for idx in range(len(category_list)):
    for i in range(idx+1, len(category_list)):
        if (len(category_list[idx]["Entity Values"]) == 0) or (len(category_list[i]["Entity Values"]) == 0):
            continue
        score = find_similarity(category_list[idx]["Entity Values"], category_list[i]["Entity Values"])
        
        lst.append([category_list[idx]["Job Id"], 
                    category_list[idx]["Job Id"], 
                    score])
        if score > 0.004:
            print(score)
# Out:
# 0.012000000000000004
# 0.006
# 0.005
# 0.007
# 0.005
# 0.006
# 0.005
# 0.005
# 0.015
# 0.005
# 0.005
# 0.006
# 0.005
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [46], in <cell line: 2>()
#       4 if (len(category_list[idx]["Entity Values"]) == 0) or (len(category_list[i]["Entity Values"]) == 0):
#       5     continue
# ----> 6 score = find_similarity(category_list[idx]["Entity Values"], category_list[i]["Entity Values"])
#       8 lst.append([category_list[idx]["Job Id"],
#       9             category_list[idx]["Job Id"],
#      10             score])
#      11 if score > 0.004:
#
# Input In [43], in find_similarity(first_set, sec_set)
#       3 for fs in first_set:
#       4     for ss in sec_set:
# ----> 5         sums += cos_similarity(fs, ss)
#       7         # If they both in tech skills, reward
#       8         if (str(fs) in tech_skills) and (str(ss) in tech_skills):
#
# Input In [42], in cos_similarity(x, y)
#       2 """ return cosine similarity between two lists """
#       3 x_embed = nlp(str(x)).vector
# ----> 4 y_embed = nlp(str(y)).vector
#       6 numerator = sum(a*b for a,b in zip(x_embed,y_embed))
#       7 squared_sum_x = sum(i*i for i in x_embed)
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\spacy\language.py:1026, in Language.__call__(self, text, disable, component_cfg)
#    1024     error_handler = proc.get_error_handler()
#    1025 try:
# -> 1026     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1027 except KeyError as e:
#    1028     # This typically happens if a component is not initialized
#    1029     raise ValueError(Errors.E109.format(name=name)) from e
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\spacy\pipeline\transition_parser.pyx:253, in spacy.pipeline.transition_parser.Parser.predict()
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\spacy\pipeline\transition_parser.pyx:274, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\thinc\model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\spacy\ml\tb_framework.py:33, in forward(model, X, is_train)
#      32 def forward(model, X, is_train):
# ---> 33     step_model = ParserStepModel(
#      34         X,
#      35         model.layers,
#      36         unseen_classes=model.attrs["unseen_classes"],
#      37         train=is_train,
#      38         has_upper=model.attrs["has_upper"],
#      39     )
#      41     return step_model, step_model.finish_steps
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\spacy\ml\parser_model.pyx:213, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File D:\Anaconda3\envs\chtenv\lib\site-packages\thinc\layers\linear.py:35, in forward(model, X, is_train)
#      33 W = cast(Floats2d, model.get_param("W"))
#      34 b = cast(Floats1d, model.get_param("b"))
# ---> 35 Y = model.ops.gemm(X, W, trans2=True)
#      36 Y += b
#      38 def backprop(dY: OutT) -> InT:
#
# KeyboardInterrupt:

# %%
category_list[9]["Entity Values"]
# Out:
# [monitoring, impact, asset protection techniques, writing, speaking]

# %%
cols = ['JOB ID A', 'JOB ID B', 'Similarity Score']
lst = []
for idx in range(len(category_list)):
    for i in range(idx+1, len(category_list)):
        if (len(category_list[idx]["Entity Values"]) == 0) or (len(category_list[i]["Entity Values"]) == 0):
            continue
        score = find_similarity(category_list[idx]["Entity Values"], category_list[i]["Entity Values"])
        
        lst.append([category_list[idx]["Job Id"], 
                    category_list[idx]["Job Id"], 
                    score])

# %%
df
# Out:
#                                   Job Id                      Job Title  \
# 0       89c41c519c3c491929e3082f0ee1d557           Editor, Celebrations
# 1       ac0c91f394fa77a00ad72ee3440cb4b7           Software Engineer II
# 2       4b5748411c4496f56ef33645a27840e0   Principal Software Architect
# 3       7a7dac1bc98365216833008c0fbd063d       Strategy Program Manager
# 4       304aff90fd39fead183f48206f4070c7        Senior Contract Manager
# ...                                  ...                            ...
# 188622  459849bc27bbcb163fb705af2f01e678       Research Assistant I Lab
# 188623  217b96a9bc7f005fbb75ee4c1cc40932         Finance and Admin Coor
# 188624  f8fd3beb5dc778800272cf58aa9e8bb4               Systems Engineer
# 188625  a1e3777919425e3b6c1a8217fbefa7af  Property Operations Assistant
# 188626  cac387011b484822610fceae3f11f763       Business Systems Analyst
#
#           SOC Code                                    Job Description  \
# 0       27-3041.00  <br/><br/>Gannett Co., Inc. (NYSE: GCI) is a s...
# 1       51-8021.00  Overview </b>       <br/><br/>Reporting to the...
# 2       17-1011.00  <br/> <br/>Digital technology has forever chan...
# 3       27-2012.03  <br/> <br/> <b>Build your future with Sovos</b...
# 4       11-9199.00  Description<br/> <br/>LaBella Associates was e...
# ...            ...                                                ...
# 188622  25-1191.00  </title></head><body><b>Auto req ID</b><br/> <...
# 188623  43-1011.00  </title></head><body><b>Auto req ID</b><br/> <...
# 188624  15-1199.02  </title></head><body><b>Auto req ID</b><br/> <...
# 188625  13-1199.00  </title></head><body><b>Auto req ID</b><br/> <...
# 188626  15-1121.00  </title></head><body><b>Auto req ID</b><br/> <...
#
#                   Company Name  \
# 0                      Gannett
# 1                          ERT
# 2       Sovos Compliance, LLC.
# 3       Sovos Compliance, LLC.
# 4           LaBella Associates
# ...                        ...
# 188622      Harvard University
# 188623      Harvard University
# 188624      Harvard University
# 188625      Harvard University
# 188626      Harvard University
#
#                                                    Skills  \
# 0                      [Local Media, Editing, Journalism]
# 1       [Java, Application Architecture, CI, Data Stru...
# 2       [Java, CSS, Government Compliance, Global Comp...
# 3       [Government Compliance, Global Compliance, Com...
# 4                                   [Legal, Disciplinary]
# ...                                                   ...
# 188622  [In Vivo, Molecular Biology, Cloning, Gel Elec...
# 188623               [Accounting, General Administration]
# 188624  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 188625                                                NaN
# 188626  [User Acceptance Testing, Data Integrity, HTTP...
#
#                                             Qualification        City  \
# 0       [Bachelor of Journalism (B.J.), Master of Jour...      Boston
# 1                 [Bachelor of Computer Science (B.C.S.)]     Medford
# 2                                                     NaN  Wilmington
# 3                                                     NaN  Wilmington
# 4       [Bachelor of Engineering (B.E./B.Eng.), Any Ba...      Boston
# ...                                                   ...         ...
# 188622                                                NaN      Boston
# 188623                                                NaN   Cambridge
# 188624                                                NaN   Cambridge
# 188625                                                NaN   Cambridge
# 188626                                                NaN   Cambridge
#
#                 State  Zipcode Job Opening Date Job Closing Date  Status  \
# 0       Massachusetts   2108.0       2021-09-23       2021-09-30  CLOSED
# 1       Massachusetts   2155.0       2021-04-29       2021-09-30  CLOSED
# 2       Massachusetts   1887.0       2021-01-29       2021-09-30  CLOSED
# 3       Massachusetts   1887.0       2021-08-27       2021-09-30  CLOSED
# 4       Massachusetts   2108.0       2021-03-11       2021-09-30  CLOSED
# ...               ...      ...              ...              ...     ...
# 188622  Massachusetts   2108.0       2021-07-10              NaN    OPEN
# 188623  Massachusetts   2138.0       2021-06-25              NaN    OPEN
# 188624  Massachusetts   2138.0       2021-07-03              NaN    OPEN
# 188625  Massachusetts   2138.0       2021-05-15              NaN    OPEN
# 188626  Massachusetts   2138.0       2021-06-19              NaN    OPEN
#
#                      Website Url
# 0        https://www.gannett.com
# 1             http://www.ert.com
# 2              https://sovos.com
# 3              https://sovos.com
# 4       http://www.labellapc.com
# ...                          ...
# 188622       https://harvard.edu
# 188623       https://harvard.edu
# 188624       https://harvard.edu
# 188625       https://harvard.edu
# 188626       https://harvard.edu
#
# [188627 rows x 14 columns]

# %%
# define columns to normalize
x = df.iloc[:,9:10]

#normalize values in first two columns only 
df.iloc[:,9:10] = (x-x.min())/ (x.max() - x.min())
df
# Out:
#                                   Job Id                      Job Title  \
# 0       89c41c519c3c491929e3082f0ee1d557           Editor, Celebrations
# 1       ac0c91f394fa77a00ad72ee3440cb4b7           Software Engineer II
# 2       4b5748411c4496f56ef33645a27840e0   Principal Software Architect
# 3       7a7dac1bc98365216833008c0fbd063d       Strategy Program Manager
# 4       304aff90fd39fead183f48206f4070c7        Senior Contract Manager
# ...                                  ...                            ...
# 188622  459849bc27bbcb163fb705af2f01e678       Research Assistant I Lab
# 188623  217b96a9bc7f005fbb75ee4c1cc40932         Finance and Admin Coor
# 188624  f8fd3beb5dc778800272cf58aa9e8bb4               Systems Engineer
# 188625  a1e3777919425e3b6c1a8217fbefa7af  Property Operations Assistant
# 188626  cac387011b484822610fceae3f11f763       Business Systems Analyst
#
#           SOC Code                                    Job Description  \
# 0       27-3041.00  <br/><br/>Gannett Co., Inc. (NYSE: GCI) is a s...
# 1       51-8021.00  Overview </b>       <br/><br/>Reporting to the...
# 2       17-1011.00  <br/> <br/>Digital technology has forever chan...
# 3       27-2012.03  <br/> <br/> <b>Build your future with Sovos</b...
# 4       11-9199.00  Description<br/> <br/>LaBella Associates was e...
# ...            ...                                                ...
# 188622  25-1191.00  </title></head><body><b>Auto req ID</b><br/> <...
# 188623  43-1011.00  </title></head><body><b>Auto req ID</b><br/> <...
# 188624  15-1199.02  </title></head><body><b>Auto req ID</b><br/> <...
# 188625  13-1199.00  </title></head><body><b>Auto req ID</b><br/> <...
# 188626  15-1121.00  </title></head><body><b>Auto req ID</b><br/> <...
#
#                   Company Name  \
# 0                      Gannett
# 1                          ERT
# 2       Sovos Compliance, LLC.
# 3       Sovos Compliance, LLC.
# 4           LaBella Associates
# ...                        ...
# 188622      Harvard University
# 188623      Harvard University
# 188624      Harvard University
# 188625      Harvard University
# 188626      Harvard University
#
#                                                    Skills  \
# 0                      [Local Media, Editing, Journalism]
# 1       [Java, Application Architecture, CI, Data Stru...
# 2       [Java, CSS, Government Compliance, Global Comp...
# 3       [Government Compliance, Global Compliance, Com...
# 4                                   [Legal, Disciplinary]
# ...                                                   ...
# 188622  [In Vivo, Molecular Biology, Cloning, Gel Elec...
# 188623               [Accounting, General Administration]
# 188624  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 188625                                                NaN
# 188626  [User Acceptance Testing, Data Integrity, HTTP...
#
#                                             Qualification        City  \
# 0       [Bachelor of Journalism (B.J.), Master of Jour...      Boston
# 1                 [Bachelor of Computer Science (B.C.S.)]     Medford
# 2                                                     NaN  Wilmington
# 3                                                     NaN  Wilmington
# 4       [Bachelor of Engineering (B.E./B.Eng.), Any Ba...      Boston
# ...                                                   ...         ...
# 188622                                                NaN      Boston
# 188623                                                NaN   Cambridge
# 188624                                                NaN   Cambridge
# 188625                                                NaN   Cambridge
# 188626                                                NaN   Cambridge
#
#                 State   Zipcode Job Opening Date Job Closing Date  Status  \
# 0       Massachusetts  0.618781       2021-09-23       2021-09-30  CLOSED
# 1       Massachusetts  0.645053       2021-04-29       2021-09-30  CLOSED
# 2       Massachusetts  0.495249       2021-01-29       2021-09-30  CLOSED
# 3       Massachusetts  0.495249       2021-08-27       2021-09-30  CLOSED
# 4       Massachusetts  0.618781       2021-03-11       2021-09-30  CLOSED
# ...               ...       ...              ...              ...     ...
# 188622  Massachusetts  0.618781       2021-07-10              NaN    OPEN
# 188623  Massachusetts  0.635551       2021-06-25              NaN    OPEN
# 188624  Massachusetts  0.635551       2021-07-03              NaN    OPEN
# 188625  Massachusetts  0.635551       2021-05-15              NaN    OPEN
# 188626  Massachusetts  0.635551       2021-06-19              NaN    OPEN
#
#                      Website Url
# 0        https://www.gannett.com
# 1             http://www.ert.com
# 2              https://sovos.com
# 3              https://sovos.com
# 4       http://www.labellapc.com
# ...                          ...
# 188622       https://harvard.edu
# 188623       https://harvard.edu
# 188624       https://harvard.edu
# 188625       https://harvard.edu
# 188626       https://harvard.edu
#
# [188627 rows x 14 columns]

# %%
df_similarities = pd.DataFrame(lst, columns=cols)
